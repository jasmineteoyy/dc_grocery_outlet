# %%
import PIL
PIL.__version__
# Out:
# '9.0.1'

# %%
import boto3
import sys
import os
import pandas as pd
import numpy as np
import csv
import io
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import pickle
import pprint
import torch
import torchvision
from torchvision import datasets, models, transforms


import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
np.random.seed(420)

# %%
df = pd.read_csv('UPC-Images-Sample-Labeled.csv').drop(['Short Description', 'ItemNumber', 'SubClass', 'Department', 'class_subclass', 'label'], axis = 1)
df.head()
# Out:
#                        Brand Size  Measure  Class  \
# 0  Covergirl                    1  Asst        82
# 1  Covergirl                    1  Asst        82
# 2  Papaya                       1  Count       70
# 3  Papaya                       1  Each        70
# 4  Cantaloupe                   1  Each        70
#
#                            Long Description                ImageList
# 0  C/GIRL LIP BALM JUMBO GLOSS FSHBOWL       prod/00000000880817.jpg
# 1  C/GIRL LIP BALM JUMBO GLOSS FSHBOWL       prod/00000000893015.jpg
# 2  PAPAYA 5800                               prod/00000000005800.jpg
# 3  PAPAYA                                    prod/00000000005800.jpg
# 4  CANTALOUPE                                prod/00000000005256.jpg

# %%
df.Brand = df.Brand.str.lower()
df = df.sort_values(by='Brand', ascending=True)
no_dupes_df = df.drop_duplicates("ImageList")
no_dupes_df.shape
# Out:
# (132380, 6)

# %%
brand_df = no_dupes_df[no_dupes_df.Brand.notna()]
brand_df.shape
# Out:
# (132380, 6)

# %%
print('Number of brands with <= 10 images: ' + str(sum(brand_df.groupby('Brand').size() <= 10)))
# Out:
# Number of brands with <= 10 images: 13989

# %%
brands_10_or_less = brand_df.groupby('Brand').filter(lambda subdf: len(subdf) <= 10)['Brand']
brands_10_or_less
# Out:
# 131360     formula 1
# 88901      hillshire
# 67950      hormel
# 19237      natierra
# 130394     smithfield
#                     ...
# 90764     zuru
# 30632     zynergy 2013
# 109471    zzand
# 109486    zzand
# 44844     zzzquil sleep aid
# Name: Brand, Length: 38469, dtype: object

# %%
ten_or_less_df = brand_df[brand_df['Brand'].isin(brands_10_or_less)]
ten_or_less_df
# Out:
#                             Brand Size  Measure  Class  \
# 131360   formula 1                  10  Ounce       98
# 88901    hillshire                   9  Ounce       26
# 67950    hormel                      6  Ounce       18
# 19237    natierra                  2.5  Ounce       86
# 130394   smithfield                  8  Ounce       26
# ...                           ...  ...      ...    ...
# 90764   zuru                       100  Count       97
# 30632   zynergy 2013               750  ML          84
# 109471  zzand                        1  Set         97
# 109486  zzand                        1  Each        97
# 44844   zzzquil sleep aid           12  Count       82
#
#                                 Long Description                ImageList
# 131360  FORMULA 1 615006W PROTECTANT SPRAY        prod/00007109915006.jpg
# 88901   HILLSHIRE THIN BROWN SUGAR HAM LMT        prod/00004450097756.jpg
# 67950   HORMEL LOW FAT PEPPERONI SHIPPER          prod/00003760012114.jpg
# 19237   NATIERRA CHOC BANANA SLICES               prod/00812907015113.jpg
# 130394  SMITHFIELD PRIME FRESH 82247 SMOKED HAM   prod/00007080082247.jpg
# ...                                          ...                      ...
# 90764   ZURU 01213Q BUNCH O BALLOONS              prod/00845218011260.jpg
# 30632   ZYNERGY ZINFANDEL OLD VINE LODI 2013      prod/00071670104412.jpg
# 109471  ZZAND 79685/496 CONSTRUCT/MONSTER TRUCK   prod/00653899794965.jpg
# 109486  ZZAND 78578 SUPER STATION                 prod/00653899785789.jpg
# 44844   ZZZQUIL SLEEP AID LIQUICAPS 84886871      prod/00032390001839.jpg
#
# [38469 rows x 6 columns]

# %%
more_than_10_df = brand_df[~brand_df['Brand'].isin(brands_10_or_less)]
more_than_10_df
# Out:
#                             Brand Size  Measure  Class  \
# 145514  180 snacks                   8  Ounce       86
# 145513  180 snacks                   8  Ounce       86
# 35193   180 snacks                   8  Ounce       86
# 35194   180 snacks                   8  Ounce       86
# 145515  180 snacks                   8  Ounce       86
# ...                           ...  ...      ...    ...
# 44712   zzzquil                      2  Pack        82
# 44711   zzzquil                      2  Pack        82
# 44860   zzzquil                      2  Pack        82
# 44859   zzzquil                      2  Pack        82
# 44858   zzzquil                     12  Ounce       82
#
#                                 Long Description                ImageList
# 145514  180 SNACKS TOASTED COCONUT SQUARE         prod/00180332000579.jpg
# 145513  180 SNACKS BLUEBERRY JOY NUT CLUSTER      prod/00180332000548.jpg
# 35193   180 SNACKS ORGANIC PUMPKIN SEED CRUNCH    prod/00818562020226.jpg
# 35194   180 SNACKS ORGANIC PUMPKIN SEED CRUNCH    prod/00081856202022.jpg
# 145515  180 SNACKS CRAN ALMD NUT CLUSTER          prod/00180332000555.jpg
# ...                                          ...                      ...
# 44712   ZZZQUIL NIGHTIME VAN CHERRY 2/12Z         prod/00323900024434.jpg
# 44711   ZZZQUIL NIGHTIME VAN CHERRY 2/12Z         prod/00032390002443.jpg
# 44860   ZZZQUIL NIGHTIME ALC FREE 2/12Z 80268091  prod/00032390003859.jpg
# 44859   ZZZQUIL NIGHTIME ALC FREE 2/12Z 80268091  prod/00323900038592.jpg
# 44858   ZZZQUIL N/TIME SLEEP AID BERRY  80278368  prod/00032390003856.jpg
#
# [93911 rows x 6 columns]

# %%
s3_client = boto3.client('s3')
s3_bucket_name = 'wowimages.groceryoutlet.com'
s3_subBucket_name = 'prod'

access_key_id = "AKIASU6JPKNQUA7PRRC5"
secret_access_key = "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"

s3 = boto3.resource('s3', aws_access_key_id=access_key_id, aws_secret_access_key=secret_access_key)

bucket=s3.Bucket(s3_bucket_name)

# %%
def read_image_from_s3(bucket, key):
    """
    Load image file from s3.

    Parameters
    ----------
    bucket: string
        Bucket name
    key : string
        Path in s3 aka file name

    Returns
    -------
    np array
        Image array
    """
    
    try:
    
        obj = bucket.Object(key)
        response = obj.get()
        file_stream = response['Body']
        im = Image.open(file_stream)
    
    except:
        print("Image not Found in S3 Bucket")
        im = np.NaN
    
    
    
    return np.array(im)

# %%
def make_image_splits(df, n):
    resampled_indices = np.arange(len(df))
    np.random.shuffle(resampled_indices)
    print(resampled_indices[:10])
    for i in range(n):
        print(f"0% {i}")
        current_indices = resampled_indices[int(i/n * len(resampled_indices)): int((i+1)/n * len(resampled_indices))]
        portion_df = df.iloc[current_indices]
        curr_images = []
        for idx, row in portion_df.iterrows():
            curr_images += [read_image_from_s3(bucket, row['ImageList'])]
            if len(curr_images) == int(len(portion_df)/2):
                print(f"50% {i}")
        portion_df['image_matrix'] = curr_images
        portion_df = portion_df[[True if img.ndim == 3 else False for img in portion_df['image_matrix']]]
        portion_df["image_tensor"] = portion_df["image_matrix"].map(lambda img: transforms.Resize((224, 224))(torch.permute(torch.tensor(img), (2, 0, 1))))
        portion_np = portion_df.to_numpy()
    
        file_path = f"image_splits_10_or_less/split_{i}.pkl"
        fileObject = open(file_path, 'wb')
        
        pickle.dump(portion_np, fileObject)

# %%
def read_make_image_splits(file):
    import pprint, pickle

    pkl_file = open(file, 'rb')

    data1 = pickle.load(pkl_file)
    pkl_file.close()
    
    return data1

# %%
make_image_splits(df=ten_or_less_df, n=50)
# Out:
# [21334 19407 15671 21682  6347 34697 28566 14968 35171 28185]
# 0% 0
# 50% 0
# 0% 1
# 50% 1
# 0% 2
# 50% 2
# 0% 3
# 50% 3
# 0% 4
# 50% 4
# 0% 5
# 50% 5
# 0% 6
# 50% 6
# 0% 7
# 50% 7
# 0% 8
# 50% 8
# 0% 9
# 50% 9
# 0% 10
# 50% 10
# 0% 11
# 50% 11
# 0% 12
# 50% 12
# 0% 13
# 50% 13
# 0% 14
# 50% 14
# 0% 15
# 50% 15
# 0% 16
# 50% 16
# 0% 17
# 50% 17
# 0% 18
# 50% 18
# 0% 19
# 50% 19
# 0% 20
# 50% 20
# 0% 21
# 50% 21
# 0% 22
# 50% 22
# 0% 23
# 50% 23
# 0% 24
# 50% 24
# 0% 25
# 50% 25
# 0% 26
# 50% 26
# 0% 27
# 50% 27
# 0% 28
# 50% 28
# 0% 29
# 50% 29
# 0% 30
# 50% 30
# 0% 31
# 50% 31
# 0% 32
# 50% 32
# 0% 33
# 50% 33
# 0% 34
# 50% 34
# 0% 35
# 50% 35
# 0% 36
# 50% 36
# 0% 37
# 50% 37
# 0% 38
# 50% 38
# 0% 39
# 50% 39
# 0% 40
# 50% 40
# 0% 41
# 50% 41
# 0% 42
# 50% 42
# 0% 43
# 50% 43
# 0% 44
# 50% 44
# 0% 45
# 50% 45
# 0% 46
# 50% 46
# 0% 47
# 50% 47
# 0% 48
# 50% 48
# 0% 49
# 50% 49
